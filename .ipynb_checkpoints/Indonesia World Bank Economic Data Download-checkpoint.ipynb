# %% [markdown]
# world bankの以下のウェブサイトからダウンロードした csvファイルの最初の４行の不要部分を消去する。
# https://data.worldbank.org/country/vietnam?view=chart

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("API_IDN_DS2_en_csv_v2_5457279.csv", encoding ='utf-8')

# %%
df.shape
# Out:
# (1478, 67)

# %%
df1 = df.drop(["Country Name", "Country Code", "Indicator Code"], axis = 1)

# %%
df1 = df1.set_index('Indicator Name')

# %%
df2 = df1.iloc[:, 40:]

# %%
df2.head()
# Out:
#                                                          2000  2001      2002  \
# Indicator Name
# Intentional homicides, female (per 100,000 female)        NaN   NaN       NaN
# Battle-related deaths (number of people)                  NaN   NaN       NaN
# Voice and Accountability: Percentile Rank           12.437811   NaN  8.955224
# Transport services (% of commercial service exp...        NaN   NaN       NaN
# Computer, communications and other services (% ...        NaN   NaN       NaN
#
#                                                         2003      2004  \
# Indicator Name
# Intentional homicides, female (per 100,000 female)       NaN       NaN
# Battle-related deaths (number of people)                 NaN       NaN
# Voice and Accountability: Percentile Rank           8.457711  9.134615
# Transport services (% of commercial service exp...       NaN       NaN
# Computer, communications and other services (% ...       NaN       NaN
#
#                                                         2005      2006  \
# Indicator Name
# Intentional homicides, female (per 100,000 female)       NaN       NaN
# Battle-related deaths (number of people)                 NaN       NaN
# Voice and Accountability: Percentile Rank           8.653846  7.692307
# Transport services (% of commercial service exp...       NaN       NaN
# Computer, communications and other services (% ...       NaN       NaN
#
#                                                         2007      2008  \
# Indicator Name
# Intentional homicides, female (per 100,000 female)       NaN       NaN
# Battle-related deaths (number of people)                 NaN       NaN
# Voice and Accountability: Percentile Rank           8.173077  8.173077
# Transport services (% of commercial service exp...       NaN       NaN
# Computer, communications and other services (% ...       NaN       NaN
#
#                                                         2009  ...       2013  \
# Indicator Name                                                ...
# Intentional homicides, female (per 100,000 female)       NaN  ...        NaN
# Battle-related deaths (number of people)                 NaN  ...        NaN
# Voice and Accountability: Percentile Rank           8.056872  ...  10.798122
# Transport services (% of commercial service exp...       NaN  ...        NaN
# Computer, communications and other services (% ...       NaN  ...        NaN
#
#                                                         2014       2015  \
# Indicator Name
# Intentional homicides, female (per 100,000 female)       NaN        NaN
# Battle-related deaths (number of people)                 NaN        NaN
# Voice and Accountability: Percentile Rank           9.359606  10.344828
# Transport services (% of commercial service exp...       NaN        NaN
# Computer, communications and other services (% ...       NaN        NaN
#
#                                                          2016       2017  \
# Indicator Name
# Intentional homicides, female (per 100,000 female)        NaN        NaN
# Battle-related deaths (number of people)                  NaN        NaN
# Voice and Accountability: Percentile Rank           10.344828  10.344828
# Transport services (% of commercial service exp...        NaN        NaN
# Computer, communications and other services (% ...        NaN        NaN
#
#                                                         2018       2019  \
# Indicator Name
# Intentional homicides, female (per 100,000 female)       NaN        NaN
# Battle-related deaths (number of people)                 NaN        NaN
# Voice and Accountability: Percentile Rank           8.212561  11.594203
# Transport services (% of commercial service exp...       NaN        NaN
# Computer, communications and other services (% ...       NaN        NaN
#
#                                                          2020       2021  2022
# Indicator Name
# Intentional homicides, female (per 100,000 female)        NaN        NaN   NaN
# Battle-related deaths (number of people)                  NaN        NaN   NaN
# Voice and Accountability: Percentile Rank           11.594203  13.043478   NaN
# Transport services (% of commercial service exp...        NaN        NaN   NaN
# Computer, communications and other services (% ...        NaN        NaN   NaN
#
# [5 rows x 23 columns]

# %%
allindex=list(df2.index.tolist())
#allindex

# %%
indexlist = pd.DataFrame(allindex)
indexlist.to_csv('result/test.csv')

# %%
# make up a list of one word with capital letters. Please give the key_word to list up indicators with the word.
key_word = 'GDP per capita'
capitalized = key_word.capitalize()
key_words_list = [key_word, capitalized]

# %%
possible_index = []
for i in indexlist[0]:
    for j in key_words_list:
        if j in i:
            possible_index.append(i)

# %%
possible_index
# Out:
# ['GDP per capita, PPP (current international $)',
#  'GDP per capita (current LCU)',
#  'GDP per capita, PPP (constant 2017 international $)',
#  'GDP per capita (constant 2015 US$)',
#  'GDP per capita growth (annual %)',
#  'GDP per capita (constant LCU)',
#  'GDP per capita (current US$)',
#  'Government expenditure per student, tertiary (% of GDP per capita)',
#  'Government expenditure per student, primary (% of GDP per capita)',
#  'Government expenditure per student, secondary (% of GDP per capita)']

# %%
df3 = df2.loc[possible_index]
df4 = df3.dropna(thresh=11)

# %%
df4 = df4.astype(float)
#df4.iloc[0]

# %%
item_numbers = len(df4)

# %%
fig, ax = plt.subplots(item_numbers, figsize=(6, 18 ))

for i in range(item_numbers):
    ax[i].plot(df4.iloc[i])
    ax[i].set_title (df4.index[i])
    ax[i].tick_params(axis='x', labelrotation=90)
    ax[i].grid()
fig.tight_layout(rect=[0,0,1,0.96])    
plt.savefig("result/key_word.jpg")
